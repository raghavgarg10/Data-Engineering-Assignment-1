# %% [markdown]
# # Assignment 1 - Basic Data Exploration and Cleaning Using Pandas
#
# # Submitted By :
# Raghav_MMDU
#
# # Role :
# Data Engineer
#
# # Objective :
#
# The main objective of this assignment is to perform essential data exploration and data cleaning tasks using the Pandas library in Python. The assignment involves working with a CSV dataset to analyze its structure, manage missing and duplicate values, apply basic filtering operations, generate new derived columns, and prepare a clean dataset suitable for further analysis.

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
print("Pandas library imported successfully!")
# Out:
# Pandas library imported successfully!

# %% [markdown]
# # 1. Load a CSV dataset into a Pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv("data/tshirts.csv")
df
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 2     17404018             Mast & Harbour
# 3     22143924                Urbano Plus
# 4     14619398                    ScoldMe
# 5      8901821               UNDER ARMOUR
# 6       919032                   Roadster
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 13    13591994                      Camey
# 14    21439050                      Kappa
# 15    13615634            U.S. Polo Assn.
# 16    13620624                   Roadster
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# ...

# %% [markdown]
# # 2. Explore data (head/tail, shape, columns, data types).

# %%
# Display first 5 rows

df.head()
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0           1099      47.0  "₹1,099.00"      INR
# 1            899       NaN    "₹899.00"      INR
# 2            999       NaN    "₹999.00"      INR
# 3           1099      45.0  "₹1,099.00"      INR
# 4           1598      55.0    "₹719.00"      INR
#
# ...

# %%
# Display last 5 rows

df.tail()
# Out:
#     product_id           title  \
# 34    22629260             max
# 35    19291812  Mad Over Print
# 36    19206288        FERANOID
# 37    19264534  Flying Machine
# 38    19264536  Flying Machine
#
#                                   product_description  rating  ratings_count  \
# 34          Striped Polo Collar Short Sleeves T-shirt     4.4              7
# 35             Women Black Love Wins Oversize T-shirt     4.8              5
# 36          Men Purple Henley Neck Bio Finish T-shirt     4.2             21
# 37  Men Black & White Printed Pure Cotton Slim Fit...     4.0            102
# 38  Men Rust Orange Melange Pure Cotton Slim Fit T...     3.8             60
#
#     initial_price  discount final_price currency  \
# 34            799      40.0   "₹479.00"      INR
# 35           1599      58.0   "₹671.00"      INR
# 36           1199      50.0   "₹599.00"      INR
# 37            999      61.0   "₹389.00"      INR
# 38           1299      61.0   "₹506.00"      INR
#
# ...

# %%
# Shape of dataset
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (39, 24)

# %%
# Column names
print(list(df.columns))
# Out:
# ['product_id', 'title', 'product_description', 'rating', 'ratings_count', 'initial_price', 'discount', 'final_price', 'currency', 'images', 'delivery_options', 'product_details', 'breadcrumbs', 'product_specifications', 'amount_of_stars', 'what_customers_said', 'seller_name', 'sizes', 'videos', 'seller_information', 'variations', 'best_offer', 'more_offers', 'category']

# %%
# Data types of each column

print(df.dtypes)
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %%
# Full info
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              39 non-null     int64
#  1   title                   39 non-null     str
#  2   product_description     39 non-null     str
#  3   rating                  39 non-null     float64
#  4   ratings_count           39 non-null     int64
#  5   initial_price           39 non-null     int64
#  6   discount                32 non-null     float64
#  7   final_price             39 non-null     str
#  8   currency                39 non-null     str
#  9   images                  39 non-null     str
#  10  delivery_options        39 non-null     str
#  11  product_details         39 non-null     str
#  12  breadcrumbs             39 non-null     str
#  13  product_specifications  39 non-null     str
#  14  amount_of_stars         39 non-null     str
# ...

# %% [markdown]
# # 3. Handle missing values (identify, fill/drop).

# %%
# Checking missing values in dataset

print(df.isnull().sum())
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   7
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said        9
# seller_name               21
# sizes                      0
# videos                    29
# seller_information        21
# variations                25
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
# Removing columns with too many missing values

df = df.drop(columns=[
    'seller_name',
    'videos',
    'variations'
])

print(df.isnull().sum())
# Out:
# product_id                 0
# title                      0
# product_description        0
# rating                     0
# ratings_count              0
# initial_price              0
# discount                   7
# final_price                0
# currency                   0
# images                     0
# delivery_options           0
# product_details            0
# breadcrumbs                0
# product_specifications     0
# amount_of_stars            0
# what_customers_said        9
# sizes                      0
# seller_information        21
# best_offer                 0
# more_offers                0
# category                   0
# dtype: int64

# %%
# Filling missing values in the dataset

df['discount'] = df['discount'].fillna('No Discount')

df['seller_information'] = df['seller_information'].fillna('Seller Details Unavailable')

df['what_customers_said'] = df['what_customers_said'].fillna('Customers Have Not Reviewed Yet')

print(df.isnull().sum())
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# sizes                     0
# seller_information        0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %% [markdown]
#  # 4. Perform basic operations (filter rows, select columns).

# %%
# Selecting specific columns

selected_columns = df[['title', 'final_price', 'rating']]

print(selected_columns)
# Out:
#                         title  final_price  rating
# 0                       ether  "₹1,099.00"     4.4
# 1              Mast & Harbour    "₹899.00"     4.2
# 2              Mast & Harbour    "₹999.00"     3.9
# 3                 Urbano Plus  "₹1,099.00"     3.2
# 4                     ScoldMe    "₹719.00"     0.0
# 5                UNDER ARMOUR  "₹1,999.00"     4.3
# 6                    Roadster    "₹899.00"     3.8
# 7              Tommy Hilfiger  "₹2,799.00"     4.4
# 8                       WROGN  "₹1,599.00"     4.2
# 9                    Roadster    "₹999.00"     4.2
# 10             Tommy Hilfiger  "₹1,999.00"     4.4
# 11                   Roadster    "₹799.00"     4.1
# 12                       Puma  "₹3,999.00"     4.4
# 13                      Camey    "₹999.00"     3.5
# 14                      Kappa    "₹599.00"     3.2
# 15            U.S. Polo Assn.  "₹1,699.00"     4.5
# 16                   Roadster  "₹1,399.00"     4.0
# ...

# %%
# Filtering rows based on condition

filtered_rows = df[df['rating'] > 4]

print(filtered_rows)
# Out:
#     product_id                      title  \
# 0     17352320                      ether
# 1     17403950             Mast & Harbour
# 5      8901821               UNDER ARMOUR
# 7     18817326             Tommy Hilfiger
# 8      8426447                      WROGN
# 9     20355284                   Roadster
# 10    18818696             Tommy Hilfiger
# 11     9213113                   Roadster
# 12    13511732                       Puma
# 15    13615634            U.S. Polo Assn.
# 17    13502414                       Puma
# 18    13621134                   Roadster
# 19    17686030          Allen Solly Tribe
# 20    13616400             Arrow New York
# 21    13480864                Aeropostale
# 22    13622338                   Roadster
# 25    16277914                       Parx
# 26    16292318                   Bewakoof
# 27    19201678              Tokyo Talkies
# 28    16923916                Monte Carlo
# 30    20085320                    BULLMER
# ...

# %% [markdown]
# # 5. Remove duplicates.

# %%
# Checking duplicate rows

print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# Removing duplicate rows

df = df.drop_duplicates()

print("Duplicates removed successfully!")
# Out:
# Duplicates removed successfully!

# %% [markdown]
# # 6. Create a Derived Column (total_amount = price * quantity)

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("data/tshirts.csv")

# Show columns
df[['initial_price', 'final_price']].head()
# Out:
#    initial_price  final_price
# 0           1099  "₹1,099.00"
# 1            899    "₹899.00"
# 2            999    "₹999.00"
# 3           1099  "₹1,099.00"
# 4           1598    "₹719.00"

# %%
df['final_price'] = df['final_price'].str.replace('₹', '')

df['final_price'] = df['final_price'].str.replace(',', '')

df['final_price'] = df['final_price'].str.replace('"', '')

df['final_price'] = df['final_price'].astype(float)

# %%
df['price_difference'] = df['initial_price'] - df['final_price']

# %%
df.head()
# Out:
#    product_id           title  \
# 0    17352320           ether
# 1    17403950  Mast & Harbour
# 2    17404018  Mast & Harbour
# 3    22143924     Urbano Plus
# 4    14619398         ScoldMe
#
#                                  product_description  rating  ratings_count  \
# 0  Kora Collection Blue Sustainable Naturally Dye...     4.4             70
# 1          Men Mint Green Typography Printed T-shirt     4.2            200
# 2       Men Blue & White Striped Regular Fit T-shirt     3.9             72
# 3             Size Typography Printed Cotton T-shirt     3.2              6
# 4     Women Multicoloured Pack Of 2 Slim Fit T-shirt     0.0              0
#
#    initial_price  discount  final_price currency  \
# 0           1099      47.0       1099.0      INR
# 1            899       NaN        899.0      INR
# 2            999       NaN        999.0      INR
# 3           1099      45.0       1099.0      INR
# 4           1598      55.0        719.0      INR
#
# ...

# %% [markdown]
# # 7. Save the Cleaned Dataset as a New CSV File

# %%
df.to_csv("cleaned_data/cleaned_tshirts.csv", index=False)

# %% [markdown]
# # Assignment Summary
#
# In this assignment, data exploration and data preprocessing operations were performed using Python and the Pandas library.
#
# The following tasks were completed successfully:
#
# * Loaded the CSV dataset
# * Explored dataset structure, columns, and data types
# * Identified and handled missing values
# * Removed unnecessary columns with excessive missing data
# * Checked and removed duplicate records
# * Performed filtering and column selection operations
# * Converted data types for numerical analysis
# * Created a derived column using existing dataset columns
# * Displayed and analyzed the processed dataset
# * Prepared the dataset for further analysis and processing
#
# This assignment helped in developing a practical understanding of data preprocessing, data cleaning, and data manipulation techniques using Python and Pandas.
